# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
import numpy as np
import os
import requests
import json
from pprint import pprint
from dotenv import load_dotenv

# %%
# API Call
load_dotenv()
API_KEY = os.getenv("Yelp_API") # put your key here if you don't have a .env file in your main project folder.
headers = {'Authorization': 'Bearer %s' % API_KEY}
base_url = "https://api.yelp.com/v3/businesses/search"

# %%
stadium_data_df = pd.read_csv('Resources/stadium_coordinates.csv', dtype={
    "NFL Team": "string",
    "City": "string",
    "State": "string",
    "Stadium Name": "string",
    "Latitude": np.float64,
    "Longitude": np.float64,
    "Zip Code": "string"
})
stadium_data_df = stadium_data_df.dropna()
stadium_data_df
# Out:
#                     NFL Team             City           State  \
# 0          Arizona Cardinals         Glendale         Arizona
# 1            Atlanta Falcons          Atlanta         Georgia
# 2           Baltimore Ravens        Baltimore        Maryland
# 3              Buffalo Bills     Orchard Park        New York
# 4          Carolina Panthers        Charlotte  North Carolina
# 5              Chicago Bears          Chicago        Illinois
# 6         Cincinnati Bengals       Cincinatti            Ohio
# 7           Cleveland Browns        Cleveland            Ohio
# 8             Dallas Cowboys        Arlington           Texas
# 9             Denver Broncos           Denver        Colorado
# 10             Detroit Lions          Detroit        Michigan
# 11         Green Bay Packers        Green Bay       Wisconsin
# 12            Houston Texans          Houston           Texas
# 13        Indianapolis Colts     Indianapolis         Indiana
# 14      Jacksonville Jaguars     Jacksonville         Florida
# 15        Kansas City Chiefs      Kansas City        Missouri
# 16         Las Vegas Raiders         Paradise          Nevada
# 17      Los Angeles Chargers        Inglewood      California
# 18          Los Angeles Rams        Inglewood      California
# 19           Miami Dolphins     Miami Gardens         Florida
# 20         Minnesota Vikings      Minneapolis      Minnessota
# 21      New England Patriots       Foxborough   Massachusetts
# 22        New Orleans Saints      New Orleans       Louisiana
# 23           New York Giants  East Rutherford      New Jersey
# 24             New York Jets  East Rutherford      New Jersey
# 25       Philadelphia Eagles     Philadelphia    Pennsylvania
# 26       Pittsburgh Steelers       Pittsburgh    Pennsylvania
# 27       San Francisco 49ers      Santa Clara      California
# 28          Seattle Seahawks          Seattle      Washington
# 29       Tampa Bay Buccaners        Tampa Bay         Florida
# 30          Tennessee Titans        Nashville       Tennessee
# 31  Washington Football Team         Landover        Maryland
#
#                   Stadium Name   Latitude   Longitude Zip Code
# 0           State Farm Stadium  33.528000 -112.263000    85305
# 1        Mercedes-Benz Stadium  33.755556  -84.400000    30313
# 2             M&T Bank Stadium  39.278056  -76.622778    21230
# 3                Bills Stadium  42.774000  -78.787000    14127
# 4      Bank of America Stadium  35.225833  -80.852778    28202
# 5                Soldier Field  41.862300  -87.616700    60605
# 6           Paul Brown Stadium  39.095000  -84.516000    45202
# 7          FirstEnergy Stadium  41.506111  -81.699444    44114
# 8                 AT&T Stadium  32.747778  -97.092778    76011
# 9   Empower Field at Mile High  39.741000 -105.019700    80204
# 10                  Ford Field  42.340000  -83.045556    48226
# 11               Lambeau Field  44.501389  -88.062222    54307
# 12                 NRG Stadium  29.684722  -95.410833    77054
# 13           Lucas Oil Stadium  39.760056  -86.163806    46225
# 14             TIAA Bank Field  30.323889  -81.637500    32202
# 15           Arrowhead Stadium  39.048889  -94.483889    64129
# 16           Allegiant Stadium  36.090833 -115.183611    89118
# 17                SoFi Stadium  33.953450 -118.339200    90301
# 18                SoFi Stadium  33.953450 -118.339200    90301
# 19           Hard Rock Stadium  25.958056  -80.238889    33056
# 20           U.S. Bank Stadium  44.974000  -93.258000    55415
# 21            Gillette Stadium  42.091000  -71.264000     2035
# 22    Mercedes--Benz Superdome  29.950833  -90.081111    70112
# 23             MetLife Stadium  40.813528  -74.074361     7073
# 24             MetLife Stadium  40.813528  -74.074361     7073
# 25     Lincoln Financial Field  39.900833  -75.167500    19101
# 26                 Heinz Field  40.446667  -80.015833    15212
# 27              Levi's Stadium  37.403000 -121.970000    95054
# 28         CenturyLink Stadium  47.595200 -122.331600    98134
# 29       Raymond James Stadium  27.975833  -82.503333    33607
# 30              Nissan Stadium  36.166389  -86.771389    37213
# 31                 FedEx Field  38.904663  -76.858663    20785

# %%
# lists to store the data retrieve from Yelp
#business_name = []
#business_state = []
business_price = []
business_rating = []
business_reviews = []
number_business = []
result = []

# %%
counter = 0
search_limit = 20
file_list = os.listdir('json_files\Saturday')
nfl_teams = stadium_data_df["NFL Team"]
team_data = list(zip(file_list, nfl_teams))


for file, team in team_data:
    
    with open(f'json_files\Saturday\{file}', 'r', encoding = 'utf-8') as f:
        contents = json.loads(f.read())
        number_business.append(contents['total'])
        for i in range(search_limit):
            try:
                business_price.append(contents['businesses'][i]['price'])
                business_rating.append(contents['businesses'][i]['rating'])
                business_reviews.append(contents['businesses'][i]['review_count'])
                #business_name.append(contents['businesses'][i]['name'])
                #business_state.append(contents['businesses'][i]['location']['state'])
               
            except:
                business_price.append(np.nan)
                business_rating.append(np.nan)
                business_reviews.append(np.nan)
                #business_name.append(np.nan)
                #business_state.append(np.nan)
        
    result.append([
        business_price,
        business_rating,
        business_reviews,
        team
        ])
        
    #print(counter)
    #print(f'({latitude}, {longitude}, {city})')
    print(f'Total number of restaurants: {number_business[counter]}')
    
    business_price = []
    business_rating = []
    business_reviews = []
    business_name = []
    business_state = []
    print(counter, contents['total'], file)
    counter += 1
# Out:
# Total number of restaurants: 94
# 0 94 yelp_response_Arizona Cardinals.json
# Total number of restaurants: 706
# 1 706 yelp_response_Atlanta Falcons.json
# Total number of restaurants: 667
# 2 667 yelp_response_Baltimore Ravens.json
# Total number of restaurants: 51
# 3 51 yelp_response_Buffalo Bills.json
# Total number of restaurants: 440
# 4 440 yelp_response_Carolina Panthers.json
# Total number of restaurants: 1400
# 5 1400 yelp_response_Chicago Bears.json
# Total number of restaurants: 458
# 6 458 yelp_response_Cincinnati Bengals.json
# Total number of restaurants: 354
# 7 354 yelp_response_Cleveland Browns.json
# Total number of restaurants: 210
# 8 210 yelp_response_Dallas Cowboys.json
# Total number of restaurants: 575
# 9 575 yelp_response_Denver Broncos.json
# Total number of restaurants: 530
# 10 530 yelp_response_Detroit Lions.json
# Total number of restaurants: 120
# 11 120 yelp_response_Green Bay Packers.json
# Total number of restaurants: 180
# 12 180 yelp_response_Houston Texans.json
# Total number of restaurants: 354
# 13 354 yelp_response_Indianapolis Colts.json
# Total number of restaurants: 175
# 14 175 yelp_response_Jacksonville Jaguars.json
# Total number of restaurants: 18
# 15 18 yelp_response_Kansas City Chiefs.json
# Total number of restaurants: 758
# 16 758 yelp_response_Las Vegas Raiders.json
# Total number of restaurants: 293
# 17 293 yelp_response_Los Angeles Chargers.json
# Total number of restaurants: 293
# 18 293 yelp_response_Los Angeles Rams.json
# Total number of restaurants: 84
# 19 84 yelp_response_Miami Dolphins .json
# Total number of restaurants: 682
# 20 682 yelp_response_Minnesota Vikings.json
# Total number of restaurants: 44
# 21 44 yelp_response_New England Patriots.json
# Total number of restaurants: 946
# 22 946 yelp_response_New Orleans Saints.json
# Total number of restaurants: 133
# 23 133 yelp_response_New York Giants.json
# Total number of restaurants: 133
# 24 133 yelp_response_New York Jets.json
# Total number of restaurants: 396
# 25 396 yelp_response_Philadelphia Eagles.json
# Total number of restaurants: 380
# 26 380 yelp_response_Pittsburgh Steelers.json
# Total number of restaurants: 179
# 27 179 yelp_response_San Francisco 49ers.json
# Total number of restaurants: 1400
# 28 1400 yelp_response_Seattle Seahawks.json
# Total number of restaurants: 270
# 29 270 yelp_response_Tampa Bay Buccaners.json
# Total number of restaurants: 528
# 30 528 yelp_response_Tennessee Titans.json
# Total number of restaurants: 94
# 31 94 yelp_response_Washington Football Team.json

# %%
dollar_dict = {"$": 1, "$$": 2, "$$$": 3, "$$$$": 4}
rating_mean = []
reviews_mean = []
price_mean = []
for i in range(len(result)):
    #print(i)
    # Replace $ symbols by their number of repetitions
    result[i][0] = [dollar_dict.get(dollar, dollar) for dollar in result[i][0]]
    # Remove nan values
    result[i][0] = [i for i in result[i][0] if i is not np.nan]
    result[i][1] = [i for i in result[i][1] if i is not np.nan]
    result[i][2] = [i for i in result[i][2] if i is not np.nan]
    price_mean.append(np.mean(result[i][0]))
    rating_mean.append(np.mean(result[i][1]))
    reviews_mean.append(np.mean(result[i][2]))

# %%
#print(result)
#print(f'{rating_mean}\n{reviews_mean}\n{price_mean}')

# %%
means_df = pd.DataFrame([rating_mean, reviews_mean, price_mean]).T
means_df.columns = ("Average Ratings (1-5)","Average Number of Reviews", "Average Price (1-4)")
means_df["NFL Team"] = nfl_teams
means_df
# Out:
#     Average Ratings (1-5)  Average Number of Reviews  Average Price (1-4)  \
# 0                4.027778                 345.222222             1.722222
# 1                4.475000                1100.350000             2.050000
# 2                4.526316                 322.526316             2.000000
# 3                3.694444                  66.111111             1.888889
# 4                4.526316                 384.157895             1.947368
# 5                4.605263                1113.315789             2.263158
# 6                4.526316                 582.526316             2.210526
# 7                4.450000                 345.900000             2.000000
# 8                4.294118                 277.235294             1.705882
# 9                4.550000                 569.850000             1.900000
# 10               4.470588                 613.882353             1.882353
# 11               3.921053                 122.789474             1.789474
# 12               4.263158                 311.526316             1.684211
# 13               4.525000                 622.150000             2.050000
# 14               4.525000                 276.000000             1.650000
# 15               3.230769                  37.000000             1.307692
# 16               4.578947                1442.368421             2.157895
# 17               4.447368                 487.157895             1.684211
# 18               4.447368                 487.157895             1.684211
# 19               4.000000                  76.312500             1.625000
# 20               4.550000                 532.700000             1.950000
# 21               3.625000                 124.812500             1.812500
# 22               4.575000                 848.850000             1.850000
# 23               4.315789                 173.947368             1.736842
# 24               4.315789                 173.947368             1.736842
# 25               4.550000                 320.250000             1.850000
# 26               4.447368                 595.789474             2.157895
# 27               4.315789                 614.526316             1.842105
# 28               4.578947                 967.736842             1.894737
# 29               4.500000                 372.894737             1.736842
# 30               4.578947                1005.263158             1.947368
# 31               3.823529                 196.764706             1.764706
#
#                     NFL Team
# 0          Arizona Cardinals
# 1            Atlanta Falcons
# 2           Baltimore Ravens
# 3              Buffalo Bills
# 4          Carolina Panthers
# 5              Chicago Bears
# 6         Cincinnati Bengals
# 7           Cleveland Browns
# 8             Dallas Cowboys
# 9             Denver Broncos
# 10             Detroit Lions
# 11         Green Bay Packers
# 12            Houston Texans
# 13        Indianapolis Colts
# 14      Jacksonville Jaguars
# 15        Kansas City Chiefs
# 16         Las Vegas Raiders
# 17      Los Angeles Chargers
# 18          Los Angeles Rams
# 19           Miami Dolphins
# 20         Minnesota Vikings
# 21      New England Patriots
# 22        New Orleans Saints
# 23           New York Giants
# 24             New York Jets
# 25       Philadelphia Eagles
# 26       Pittsburgh Steelers
# 27       San Francisco 49ers
# 28          Seattle Seahawks
# 29       Tampa Bay Buccaners
# 30          Tennessee Titans
# 31  Washington Football Team

# %%
# Merge analysis dataframe with source dataframe
saturday_df = stadium_data_df.merge(means_df, on= "NFL Team", how='left')
saturday_df["Number of businesses"] = number_business
saturday_df.head()
# Out:
#             NFL Team          City           State             Stadium Name  \
# 0  Arizona Cardinals      Glendale         Arizona       State Farm Stadium
# 1    Atlanta Falcons       Atlanta         Georgia    Mercedes-Benz Stadium
# 2   Baltimore Ravens     Baltimore        Maryland         M&T Bank Stadium
# 3      Buffalo Bills  Orchard Park        New York            Bills Stadium
# 4  Carolina Panthers     Charlotte  North Carolina  Bank of America Stadium
#
#     Latitude   Longitude Zip Code  Average Ratings (1-5)  \
# 0  33.528000 -112.263000    85305               4.027778
# 1  33.755556  -84.400000    30313               4.475000
# 2  39.278056  -76.622778    21230               4.526316
# 3  42.774000  -78.787000    14127               3.694444
# 4  35.225833  -80.852778    28202               4.526316
#
#    Average Number of Reviews  Average Price (1-4)  Number of businesses
# 0                 345.222222             1.722222                    94
# 1                1100.350000             2.050000                   706
# 2                 322.526316             2.000000                   667
# 3                  66.111111             1.888889                    51
# 4                 384.157895             1.947368                   440

# %%
# Export dataframe to csv file
output_path = "Resources\saturday_ouput.csv"
saturday_df.to_csv(output_path, index=False, header=True, encoding = "utf-8")
