# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
import pandas as pd
import numpy as np
import os
import requests
import json
from pprint import pprint
sns.set()

# %%
cat_means_df = pd.read_csv("Resources/Monday_categories_ouput.csv")
cat_means_df.head()
# Out:
#             NFL Team          City           State             Stadium Name  \
# 0  Arizona Cardinals      Glendale         Arizona       State Farm Stadium
# 1    Atlanta Falcons       Atlanta         Georgia    Mercedes-Benz Stadium
# 2   Baltimore Ravens     Baltimore        Maryland         M&T Bank Stadium
# 3      Buffalo Bills  Orchard Park        New York            Bills Stadium
# 4  Carolina Panthers     Charlotte  North Carolina  Bank of America Stadium
#
#     Latitude   Longitude  Zip Code  Average Ratings (1-5)  \
# 0  33.528000 -112.263000     85305               3.136364
# 1  33.755556  -84.400000     30313               3.500000
# 2  39.278056  -76.622778     21230               3.840426
# 3  42.774000  -78.787000     14127               2.500000
# 4  35.225833  -80.852778     28202               3.773438
#
#    Average Number of Reviews  Average Price (1-4)  Number of businesses
# 0                 257.818182             2.090909                  11.0
# ...

# %%
#Set context, increase font size
sns.set_context("poster", font_scale=1.5)
#Create a figure
plt.figure(figsize=(15,20))
#Define the axis object
ax = sns.barplot(x='Average Ratings (1-5)', y='Stadium Name', data=cat_means_df, palette="OrRd")
#set paramters
ax.set(xlabel='Avg Rating (1-5)', ylabel='Stadium Name', title= "AVG Bar Rating in 2mi Radius")
plt.savefig(f'Images/Average_Bar_Rating_2miles.png', bbox_inches = 'tight')
plt.show()

# %%
#Set context, increase font size
sns.set_context("poster", font_scale=1.5)
#Create a figure
plt.figure(figsize=(15,20))
#Define the axis object
ax = sns.barplot(x='Average Number of Reviews', y='Stadium Name', data=cat_means_df, palette="Blues_d")
#set paramters
ax.set(xlabel='Avg Number of Reviews', ylabel='Stadium Name', title= "AVG # of Bar Reviews within 2 Mile Radius")
plt.savefig(f'Images/Average_number_of_reviews_Bar_category_2miles.png', bbox_inches = 'tight')
plt.show()

# %%
#Set context, increase font size
sns.set_context("poster", font_scale=1.5)
#Create a figure
plt.figure(figsize=(15,20))
#Define the axis object
ax = sns.barplot(x='Average Price (1-4)', y='Stadium Name', data=cat_means_df, palette="Greens")
#set paramters
ax.set(xlabel='Avg Price', ylabel='Stadium Name', title= "Avg Bar Price within 2 Mile Radius")
plt.savefig(f'Images/Average_Bar_Price_2miles.png', bbox_inches = 'tight')
plt.show()

# %%
#Set context, increase font size
sns.set_context("poster", font_scale=1.5)
#Create a figure
plt.figure(figsize=(15,20))
#Define the axis object
ax = sns.barplot(x='Number of businesses', y='Stadium Name', data=cat_means_df, palette="Blues_d")
#set paramters
ax.set(xlabel='Avg Price', ylabel='Stadium Name', title= "Number of Bars within 2 Mile Radius")
plt.savefig('Images/Number_bars_vs_price.png', bbox_inches = 'tight')
plt.show()
