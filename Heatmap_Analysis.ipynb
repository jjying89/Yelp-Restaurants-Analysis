# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
import numpy as np
import os
import requests
import json
from pprint import pprint
from dotenv import load_dotenv
import gmaps

# %%
# API Call
load_dotenv()

base_url = "https://api.yelp.com/v3/businesses/search"
g_key = os.getenv("g_key") # put your key here if you don't have a .env file in your main project folder.

# %% [markdown]
# ## Plotting gmaps

# %%
#NFL stadium info
stadium_data_df = pd.read_csv('Resources/stadium_coordinates_capacity.csv')
stadium_data_df.head()
# Out:
#             NFL Team          City           State             Stadium Name  \
# 0  Arizona Cardinals      Glendale         Arizona       State Farm Stadium
# 1    Atlanta Falcons       Atlanta         Georgia    Mercedes-Benz Stadium
# 2   Baltimore Ravens     Baltimore        Maryland         M&T Bank Stadium
# 3      Buffalo Bills  Orchard Park        New York            Bills Stadium
# 4  Carolina Panthers     Charlotte  North Carolina  Bank of America Stadium
#
#     Latitude   Longitude  Zip Code  Capacity
# 0  33.528000 -112.263000     85305     63400
# 1  33.755556  -84.400000     30313     71000
# 2  39.278056  -76.622778     21230     71008
# 3  42.774000  -78.787000     14127     71608
# 4  35.225833  -80.852778     28202     73778

# %%
# Saturday data
saturday1000_df = pd.read_csv('Resources/saturday1000_ouput.csv')
saturday1000_df
# Out:
#                     NFL Team             City           State  \
# 0          Arizona Cardinals         Glendale         Arizona
# 1            Atlanta Falcons          Atlanta         Georgia
# 2           Baltimore Ravens        Baltimore        Maryland
# 3              Buffalo Bills     Orchard Park        New York
# 4          Carolina Panthers        Charlotte  North Carolina
# 5              Chicago Bears          Chicago        Illinois
# 6         Cincinnati Bengals       Cincinatti            Ohio
# 7           Cleveland Browns        Cleveland            Ohio
# 8             Dallas Cowboys        Arlington           Texas
# 9             Denver Broncos           Denver        Colorado
# 10             Detroit Lions          Detroit        Michigan
# 11         Green Bay Packers        Green Bay       Wisconsin
# 12            Houston Texans          Houston           Texas
# 13        Indianapolis Colts     Indianapolis         Indiana
# 14      Jacksonville Jaguars     Jacksonville         Florida
# 15        Kansas City Chiefs      Kansas City        Missouri
# 16         Las Vegas Raiders         Paradise          Nevada
# 17      Los Angeles Chargers        Inglewood      California
# 18          Los Angeles Rams        Inglewood      California
# 19           Miami Dolphins     Miami Gardens         Florida
# 20         Minnesota Vikings      Minneapolis      Minnessota
# 21      New England Patriots       Foxborough   Massachusetts
# 22        New Orleans Saints      New Orleans       Louisiana
# 23           New York Giants  East Rutherford      New Jersey
# 24             New York Jets  East Rutherford      New Jersey
# 25       Philadelphia Eagles     Philadelphia    Pennsylvania
# 26       Pittsburgh Steelers       Pittsburgh    Pennsylvania
# 27       San Francisco 49ers      Santa Clara      California
# 28          Seattle Seahawks          Seattle      Washington
# 29       Tampa Bay Buccaners        Tampa Bay         Florida
# 30          Tennessee Titans        Nashville       Tennessee
# 31  Washington Football Team         Landover        Maryland
#
#                   Stadium Name   Latitude   Longitude  Zip Code  \
# 25               3.702703                 143.145270             1.510135
# 26               3.580702                 140.221053             1.684211
# 27               3.460265                 288.615894             1.615894
# 28               3.925439                 411.338816             1.757675
# 29               3.523196                 146.180412             1.500000
# 30               3.767857                 297.234694             1.785714
# 31               2.763158                  80.815789             1.447368
#
#     Number of businesses
# 0                     94
# 1                    705
# 2                    668
# 3                     51
# 4                    441
# 5                   1400
# 6                    458
# 7                    354
# 8                    210
# 9                    575
# 10                   530
# 11                   120
# 12                   180
# 13                   354
# 14                   175
# 15                    18
# 16                   758
# 17                   293
# 18                   293
# 19                    84
# 20                   682
# 21                    44
# 22                   946
# 23                   133
# 24                   133
# 25                   396
# 26                   380
# 27                   179
# 28                  1400
# 29                   270
# 30                   528
# 31                    94

# %%
saturday1000_df["Capacity"]= stadium_data_df.loc[:, "Capacity"]
saturday1000_df
# Out:
#                     NFL Team             City           State  \
# 0          Arizona Cardinals         Glendale         Arizona
# 1            Atlanta Falcons          Atlanta         Georgia
# 2           Baltimore Ravens        Baltimore        Maryland
# 3              Buffalo Bills     Orchard Park        New York
# 4          Carolina Panthers        Charlotte  North Carolina
# 5              Chicago Bears          Chicago        Illinois
# 6         Cincinnati Bengals       Cincinatti            Ohio
# 7           Cleveland Browns        Cleveland            Ohio
# 8             Dallas Cowboys        Arlington           Texas
# 9             Denver Broncos           Denver        Colorado
# 10             Detroit Lions          Detroit        Michigan
# 11         Green Bay Packers        Green Bay       Wisconsin
# 12            Houston Texans          Houston           Texas
# 13        Indianapolis Colts     Indianapolis         Indiana
# 14      Jacksonville Jaguars     Jacksonville         Florida
# 15        Kansas City Chiefs      Kansas City        Missouri
# 16         Las Vegas Raiders         Paradise          Nevada
# 17      Los Angeles Chargers        Inglewood      California
# 18          Los Angeles Rams        Inglewood      California
# 19           Miami Dolphins     Miami Gardens         Florida
# 20         Minnesota Vikings      Minneapolis      Minnessota
# 21      New England Patriots       Foxborough   Massachusetts
# 22        New Orleans Saints      New Orleans       Louisiana
# 23           New York Giants  East Rutherford      New Jersey
# 24             New York Jets  East Rutherford      New Jersey
# 25       Philadelphia Eagles     Philadelphia    Pennsylvania
# 26       Pittsburgh Steelers       Pittsburgh    Pennsylvania
# 27       San Francisco 49ers      Santa Clara      California
# 28          Seattle Seahawks          Seattle      Washington
# 29       Tampa Bay Buccaners        Tampa Bay         Florida
# 30          Tennessee Titans        Nashville       Tennessee
# 31  Washington Football Team         Landover        Maryland
#
#                   Stadium Name   Latitude   Longitude  Zip Code  \
# 0           State Farm Stadium  33.528000 -112.263000     85305
# 1        Mercedes-Benz Stadium  33.755556  -84.400000     30313
# 2             M&T Bank Stadium  39.278056  -76.622778     21230
# 3                Bills Stadium  42.774000  -78.787000     14127
# 4      Bank of America Stadium  35.225833  -80.852778     28202
# 5                Soldier Field  41.862300  -87.616700     60605
# 3                     51     71608
# 4                    441     73778
# 5                   1400     61500
# 6                    458     65535
# 7                    354     67895
# 8                    210     80000
# 9                    575     76125
# 10                   530     64500
# 11                   120     73128
# 12                   180     72220
# 13                   354     63000
# 14                   175     67814
# 15                    18     76416
# 16                   758     65000
# 17                   293     70240
# 18                   293     70240
# 19                    84     64767
# 20                   682     66860
# 21                    44     68756
# 22                   946     76468
# 23                   133     82566
# 24                   133     82566
# 25                   396     69144
# 26                   380     65050
# 27                   179     68500
# 28                  1400     67000
# 29                   270     65908
# 30                   528     69143
# 31                    94     79000

# %%
#clean data for gmaps
#dropped duplicate data - MetLife(NY) & SoFi(LA) Stadium
gmaps_df = saturday1000_df.drop_duplicates(subset='Stadium Name', keep='first')
gmaps_df.reset_index(inplace = True, drop = True)
gmaps_df.head()
# Out:
#             NFL Team          City           State             Stadium Name  \
# 0  Arizona Cardinals      Glendale         Arizona       State Farm Stadium
# 1    Atlanta Falcons       Atlanta         Georgia    Mercedes-Benz Stadium
# 2   Baltimore Ravens     Baltimore        Maryland         M&T Bank Stadium
# 3      Buffalo Bills  Orchard Park        New York            Bills Stadium
# 4  Carolina Panthers     Charlotte  North Carolina  Bank of America Stadium
#
#     Latitude   Longitude  Zip Code  Average Ratings (1-5)  \
# 0  33.528000 -112.263000     85305               3.000000
# 1  33.755556  -84.400000     30313               3.404537
# 2  39.278056  -76.622778     21230               3.538784
# 3  42.774000  -78.787000     14127               3.166667
# 4  35.225833  -80.852778     28202               3.635569
#
#    Average Number of Reviews  Average Price (1-4)  Number of businesses  \
# 0                 162.315789             1.473684                    94
# 1                 248.502836             1.623819                   705
# 2                 160.968553             1.706499                   668
# 3                  50.030303             1.696970                    51
# 4                 190.620991             1.670554                   441
#
#    Capacity
# 0     63400
# 1     71000
# 2     71008
# 3     71608
# 4     73778

# %%
#find number of restaurants per attendee
gmaps_df["Attendees per Restaurant"]= round(gmaps_df['Capacity'] / gmaps_df['Number of businesses'],2)
gmaps_df.head()
# Out:
# C:\Users\franc\Anaconda3\envs\BootcampEnv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             NFL Team          City           State             Stadium Name  \
# 0  Arizona Cardinals      Glendale         Arizona       State Farm Stadium
# 1    Atlanta Falcons       Atlanta         Georgia    Mercedes-Benz Stadium
# 2   Baltimore Ravens     Baltimore        Maryland         M&T Bank Stadium
# 3      Buffalo Bills  Orchard Park        New York            Bills Stadium
# 4  Carolina Panthers     Charlotte  North Carolina  Bank of America Stadium
#
#     Latitude   Longitude  Zip Code  Average Ratings (1-5)  \
# 0  33.528000 -112.263000     85305               3.000000
# 1  33.755556  -84.400000     30313               3.404537
# 2  39.278056  -76.622778     21230               3.538784
# 3  42.774000  -78.787000     14127               3.166667
# 4  35.225833  -80.852778     28202               3.635569
#
#    Average Number of Reviews  Average Price (1-4)  Number of businesses  \
# 0                 162.315789             1.473684                    94
# 1                 248.502836             1.623819                   705
# 2                 160.968553             1.706499                   668
# 3                  50.030303             1.696970                    51
# 4                 190.620991             1.670554                   441
#
#    Capacity  attendees_per_rest   Attendees per Restaurant
# 0     63400               674.47                    674.47
# 1     71000               100.71                    100.71
# 2     71008               106.30                    106.30
# 3     71608              1404.08                   1404.08
# 4     73778               167.30                    167.30

# %%
#find max value of rest_per_attendee
max_attendees_per_rest = gmaps_df["Attendees per Restaurant"].max()

print(max_attendees_per_rest )
# Out:
# 4245.33

# %%
#configure gmaps
gmaps.configure(g_key)

#template for the markers on gmap
info_box_template = """
<dl>
<dt>Team</dt><dd>{NFL Team}</dd>
<dt>City</dt><dd>{City}, {State}</dd>
<dt>Stadium</dt><dd>{Stadium Name}</dd>
<dt>Restaurants</dt><dd>{Number of businesses}</dd>
</dl>
"""
stadium_info = [info_box_template.format(**row) for index, row in gmaps_df.iterrows()]
locations = gmaps_df[["Latitude", "Longitude"]]

# %%
#looking for options?
#gmap for number of restaurants in a 2 mile radius around each stadium
#plot gmaps
fig = gmaps.figure()

#create heat layer (number of businesses)
heat_layer = gmaps.heatmap_layer(locations, weights=gmaps_df['Number of businesses'], 
                                 dissipating=False, max_intensity=1400,
                                 point_radius=3)

#add layer
fig.add_layer(heat_layer)

#add markers
markers = gmaps.symbol_layer(locations, info_box_content=stadium_info, fill_color='blue', stroke_color='blue', scale=2)
fig.add_layer(markers)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#gmap based on number of attendees per restaurant 
#plot gmaps
fig2 = gmaps.figure()

#create heat layer (Average Ratings (1-5))
heat_layer2 = gmaps.heatmap_layer(locations, weights=gmaps_df['Attendees per Restaurant'], 
                                 dissipating=False, max_intensity=max_attendees_per_rest,
                                 point_radius=2)

#add layer
fig2.add_layer(heat_layer2)

#add markers
markers2 = gmaps.symbol_layer(locations, info_box_content=stadium_info, fill_color='blue', stroke_color='blue', scale=2)
fig2.add_layer(markers2)

fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#gmap based on average ratings
#plot gmaps
fig3 = gmaps.figure()

#create heat layer (Average Ratings (1-5))
heat_layer3 = gmaps.heatmap_layer(locations, weights=gmaps_df['Average Ratings (1-5)'], 
                                 dissipating=False, max_intensity=5,
                                 point_radius=1)

#add layer
fig3.add_layer(heat_layer3)

#add markers
markers3 = gmaps.symbol_layer(locations, info_box_content=stadium_info, fill_color='blue', stroke_color='blue', scale=2)
fig3.add_layer(markers3)

fig3
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ## Interesting Data
# ### According to statistica.com, there are 660,755 restaurants in the US as of spring 2018.
# ### Roughly 2% of all resturants in the US exist within a 2 mile radius of NFL stadiums.

# %%
#according to statistica.com, there are 660,755 restaurants in the US as of spring 2018
#find total number of resturants within a 2 mile radius of all NFL stadiums
gmaps_df['Number of businesses'].sum()
# Out:
# 12520

# %%
#roughly 2% of all resturants in the US exist within a 2 mile radius of NFL stadiums
round(12519/660755, 2)
# Out:
# 0.02
