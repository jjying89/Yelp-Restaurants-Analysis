# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
import pandas as pd
import numpy as np
import os
import requests
import json
from pprint import pprint
sns.set()

# %%
cat_means_df = pd.read_csv("Resources/Monday_categories_ouput.csv")
cat_means_df
# Out:
#                 NFL Team             City           State  \
# 0      Arizona Cardinals         Glendale         Arizona
# 1        Atlanta Falcons          Atlanta         Georgia
# 2       Baltimore Ravens        Baltimore        Maryland
# 3          Buffalo Bills     Orchard Park        New York
# 4      Carolina Panthers        Charlotte  North Carolina
# 5          Chicago Bears          Chicago        Illinois
# 6     Cincinnati Bengals       Cincinatti            Ohio
# 7       Cleveland Browns        Cleveland            Ohio
# 8         Dallas Cowboys        Arlington           Texas
# 9         Denver Broncos           Denver        Colorado
# 10         Detroit Lions          Detroit        Michigan
# 11     Green Bay Packers        Green Bay       Wisconsin
# 12        Houston Texans          Houston           Texas
# 13    Indianapolis Colts     Indianapolis         Indiana
# 14  Jacksonville Jaguars     Jacksonville         Florida
# 15    Kansas City Chiefs      Kansas City        Missouri
# 16     Las Vegas Raiders         Paradise          Nevada
# 17  Los Angeles Chargers        Inglewood      California
# 18      Los Angeles Rams        Inglewood      California
# 19     Minnesota Vikings      Minneapolis      Minnessota
# 20  New England Patriots       Foxborough   Massachusetts
# 21    New Orleans Saints      New Orleans       Louisiana
# 22       New York Giants  East Rutherford      New Jersey
# 23         New York Jets  East Rutherford      New Jersey
# 24   Philadelphia Eagles     Philadelphia    Pennsylvania
# 25   Pittsburgh Steelers       Pittsburgh    Pennsylvania
# 26   San Francisco 49ers      Santa Clara      California
# 27      Seattle Seahawks          Seattle      Washington
# 28   Tampa Bay Buccaners        Tampa Bay         Florida
# 29      Tennessee Titans        Nashville       Tennessee
#
#                   Stadium Name   Latitude   Longitude  Zip Code  \
# 0           State Farm Stadium  33.528000 -112.263000     85305
# 1        Mercedes-Benz Stadium  33.755556  -84.400000     30313
# 2             M&T Bank Stadium  39.278056  -76.622778     21230
# 3                Bills Stadium  42.774000  -78.787000     14127
# 4      Bank of America Stadium  35.225833  -80.852778     28202
# 5                Soldier Field  41.862300  -87.616700     60605
# 6           Paul Brown Stadium  39.095000  -84.516000     45202
# 7          FirstEnergy Stadium  41.506111  -81.699444     44114
# 8                 AT&T Stadium  32.747778  -97.092778     76011
# 9   Empower Field at Mile High  39.741000 -105.019700     80204
# 10                  Ford Field  42.340000  -83.045556     48226
# 11               Lambeau Field  44.501389  -88.062222     54307
# 12                 NRG Stadium  29.684722  -95.410833     77054
# 13           Lucas Oil Stadium  39.760056  -86.163806     46225
# 14             TIAA Bank Field  30.323889  -81.637500     32202
# 15           Arrowhead Stadium  39.048889  -94.483889     64129
# 16           Allegiant Stadium  36.090833 -115.183611     89118
# 17                SoFi Stadium  33.953450 -118.339200     90301
# 18                SoFi Stadium  33.953450 -118.339200     90301
# 19           U.S. Bank Stadium  44.974000  -93.258000     55415
# 20            Gillette Stadium  42.091000  -71.264000      2035
# 21    Mercedes--Benz Superdome  29.950833  -90.081111     70112
# 22             MetLife Stadium  40.813528  -74.074361      7073
# 23             MetLife Stadium  40.813528  -74.074361      7073
# 24     Lincoln Financial Field  39.900833  -75.167500     19101
# 25                 Heinz Field  40.446667  -80.015833     15212
# 26              Levi's Stadium  37.403000 -121.970000     95054
# 27         CenturyLink Stadium  47.595200 -122.331600     98134
# 28       Raymond James Stadium  27.975833  -82.503333     33607
# 29              Nissan Stadium  36.166389  -86.771389     37213
#
#     Average Ratings (1-5)  Average Number of Reviews  Average Price (1-4)  \
# 0                3.136364                 257.818182             2.090909
# 1                3.500000                 393.702128             2.127660
# 2                3.840426                 233.744681             2.170213
# 3                2.500000                  30.000000             2.000000
# 4                3.773438                 258.687500             2.125000
# 5                3.601852                 400.083333             2.194444
# 6                3.846939                 186.959184             1.918367
# 7                3.541667                 182.055556             1.972222
# 8                3.404762                 151.142857             1.904762
# 9                3.814815                 319.870370             2.092593
# 10               3.683673                 254.306122             2.102041
# 11               3.111111                  51.444444             2.000000
# 12               4.000000                 138.000000             2.500000
# 13               3.808824                 234.323529             2.088235
# 14               3.888889                 276.777778             2.333333
# 15               2.500000                   7.000000             2.000000
# 16               3.791667                 755.402778             2.347222
# 17               3.500000                  95.333333             1.666667
# 18               3.500000                  95.333333             1.666667
# 19               3.500000                 339.000000             2.000000
# 20               3.866279                 386.837209             1.976744
# 21               3.900000                 174.200000             2.000000
# 22               3.900000                 174.200000             2.000000
# 23               3.868421                 225.894737             1.894737
# 24               3.734375                 238.125000             2.062500
# 25               3.727273                 523.636364             2.363636
# 26               3.838129                 444.553957             2.071942
# 27               3.600000                 316.733333             2.200000
# 28               3.808333                 300.816667             2.016667
# 29               2.500000                 105.000000             2.000000
#
#     Number of businesses
# 0                   11.0
# 1                   57.0
# 2                   55.0
# 3                    3.0
# 4                   69.0
# 5                  127.0
# 6                   57.0
# 7                   39.0
# 8                   25.0
# 9                   58.0
# 10                  65.0
# 11                  10.0
# 12                   3.0
# 13                  35.0
# 14                  12.0
# 15                   1.0
# 16                  79.0
# 17                   4.0
# 18                   4.0
# 19                   3.0
# 20                  97.0
# 21                   5.0
# 22                   5.0
# 23                  23.0
# 24                  38.0
# 25                  11.0
# 26                 154.0
# 27                  15.0
# 28                  77.0
# 29                   1.0

# %%
#Set context, increase font size
sns.set_context("poster", font_scale=1.5)
#Create a figure
plt.figure(figsize=(15,20))
#Define the axis object
ax = sns.barplot(x='Average Ratings (1-5)', y='Stadium Name', data=cat_means_df, palette="OrRd")
#set paramters
ax.set(xlabel='Avg Rating (1-5)', ylabel='Stadium Name', title= "AVG Bar Rating in 2mi Radius")
#plt.savefig(fname)
# Out:
# [Text(0, 0.5, 'Stadium Name'),
#  Text(0.5, 0, 'Avg Rating (1-5)'),
#  Text(0.5, 1.0, 'AVG Bar Rating in 2mi Radius')]

# %%
#Set context, increase font size
sns.set_context("poster", font_scale=1.5)
#Create a figure
plt.figure(figsize=(15,20))
#Define the axis object
ax = sns.barplot(x='Average Number of Reviews', y='Stadium Name', data=cat_means_df, palette="Blues_d")
#set paramters
ax.set(xlabel='Avg Number of Reviews', ylabel='Stadium Name', title= "AVG # of Bar Reviews within 2 Mile Radius")
#show the plot
# Out:
# [Text(0, 0.5, 'Stadium Name'),
#  Text(0.5, 0, 'Avg Number of Reviews'),
#  Text(0.5, 1.0, 'AVG # of Bar Reviews within 2 Mile Radius')]

# %%
#Set context, increase font size
sns.set_context("poster", font_scale=1.5)
#Create a figure
plt.figure(figsize=(15,20))
#Define the axis object
ax = sns.barplot(x='Average Price (1-4)', y='Stadium Name', data=means_df, palette="Greens")
#set paramters
ax.set(xlabel='Avg Price', ylabel='Stadium Name', title= "Avg Bar Price within 2 Mile Radius")
#show the plot
# Out:
# [Text(0, 0.5, 'Stadium Name'),
#  Text(0.5, 0, 'Avg Price'),
#  Text(0.5, 1.0, 'Avg Bar Price within 2 Mile Radius')]

# %%
#Set context, increase font size
sns.set_context("poster", font_scale=1.5)
#Create a figure
plt.figure(figsize=(15,20))
#Define the axis object
ax = sns.barplot(x='Number of businesses', y='Stadium Name', data=means_df, palette="Blues_d")
#set paramters
ax.set(xlabel='Avg Price', ylabel='Stadium Name', title= "Number of Bars within 2 Mile Radius")
#show the plot
# Out:
# [Text(0, 0.5, 'Stadium Name'),
#  Text(0.5, 0, 'Avg Price'),
#  Text(0.5, 1.0, 'Number of Bars within 2 Mile Radius')]
